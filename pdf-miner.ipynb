# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from cStringIO import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = file(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, caching=caching, check_extractable=False):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
t = convert_pdf_to_txt('Robert_Brissie_Application.pdf')
print t
# Out:
# Student	Loan	Refinancing	Application
#
# Welcome	Robert,	let's	get	started.
#
# How	did	you	hear	about	the	loan?
#
# How	did	you	hear	about	the	All-in-One?
#
# First	Name
#
# Last	Name
#
# First	Republic	Bank	Client
#
# Elodie
#
# Lorenz
#
# I	was	referred	to	a	specific	Banker
#
# Your	loan
#
# How	much	loan	are	you	applying	for?
# (Enter	$40,000	to	$300,000)
#
# $81,000
#
# Are	you	applying	with	a	co-applicant?*
#
# Without	a	co-
# applicant
#
# With	a	co-
# applicant
#
# 1
#
# 1If	you	(a)	are	using	the	income	or	assets	of	another	person	to	qualify	for	this	product,
# or	(b)	want	another	person	to	be	able	to	use	this	product,	then	that	person	is	a	co-
# applicant.	Any	married	person	can	apply	for	credit	in	his	or	her	individual	name.	If	you
# have	more	than	one	co-applicant,	please	contact	your	banker.
#
# Select	a	fixed	rate/term	option
#
# 5	years
#
# 2.35%
# APR
#
# 7	years
#
# 2.95%
# APR
#
# 10	years
#
# 3.45%
# APR
#
# 15	years
#
# 3.95%
# APR
#
# Your	monthly	payment
#
# ...

# %%
lines = t.split("\n")

# %%
m = lines.index("Mother's	Maiden	Name")
social_security_numer = lines[m + 2]
mothers_maiden_name = lines[m +  4]
c = lines.index("Citizenship")
citizenship = lines[c + 2]
al1 = lines.index("Home	Address	Line	1")
address_line1 = lines[al1 + 2]
al2 = lines.index("Address	Line	2")
address_line2 = lines[al2 + 2]
c1 = lines.index("City")
city = lines[c1 + 2]
s = lines.index("State")
state = lines[s + 2]
z = lines.index("ZIP	Code")
zip_code = lines[z + 2]
r = lines.index("in	rent	each	month?")
rent = lines[r + 2]
do = lines.index("Degree	Obtained")
degree_obtained = lines[do + 2]
ce = lines.index("Current	Employer	Name	")
current_employer = lines[ce + 2]
asi = lines.index("Annual	Base	Salary")
annual_salary = lines[asi + 2]
ab = lines.index("Annual	Bonus")
annual_bonus = lines[ab + 2]
l = lines.index("Approximate	outstanding	loan	balance")
loan_balance = lines[l + 2]

# %%
# Out:
# 'M.S.'
